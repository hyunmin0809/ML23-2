# %% [markdown]
# 바이너리와 동일한 7개의 Feature을 가지고 돌린 코드이다. 결과값이 좋지 않아 multimodel 2차에서 다시 중요도를 구한 후 feature을 다시 구했다.

# %% [markdown]
# unmon_standard10.pkl > array code

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 데이터 불러오기

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# X와 y 데이터 불러오기
file_path_1 = '/content/drive/My Drive/dataset/feature/data_arrays_1.npz'
file_path_2 = '/content/drive/My Drive/dataset/feature/data_arrays_2.npz'
file_path_3 = '/content/drive/My Drive/dataset/feature/data_arrays_3.npz'
file_path_4 = '/content/drive/My Drive/dataset/feature/data_arrays_4.npz'
file_path_5 = '/content/drive/My Drive/dataset/feature/unmon_data_1.npz'
file_path_6 = '/content/drive/My Drive/dataset/feature/unmon_data_2.npz'

# npz 파일 읽기 (allow_pickle=True 옵션 추가)
data_1 = np.load(file_path_1, allow_pickle=True)
data_2 = np.load(file_path_2, allow_pickle=True)
data_3 = np.load(file_path_3, allow_pickle=True)
data_4 = np.load(file_path_4, allow_pickle=True)

#이 밑에서부터는 unmon
data_5 = np.load(file_path_5, allow_pickle=True) #X1, X5, X6, X7, X9, X12, X14의 정보를 담고 있다
data_6 = np.load(file_path_6, allow_pickle=True) #X3, X5, X8, X11, X15, X116, X17의 정보를 담고 있다

# X 데이터 추출
# y = data_1['y']
y_mon = data_1['y']
X1_mon = data_1['X1']
X5_mon = data_2['X5']  # X1 데이터 로드
X6_mon = data_2['X6']
X7_mon = data_2['X7']
X9_mon = data_3['X9']
X12_mon = data_3['X12']  # X1 데이터 로드
X14_mon = data_4['X14']

X1_unmon = data_5['X1_unmon']
X5_unmon = data_5['X5_unmon']  # X1 데이터 로드
X6_unmon = data_5['X6_unmon']
X7_unmon = data_5['X7_unmon']
X9_unmon = data_5['X9_unmon']
X12_unmon = data_5['X12_unmon']  # X1 데이터 로드
X14_unmon = data_5['X14_unmon']


data_mon = pd.DataFrame({
    'Feature1': X1_mon,
    'Feature5': X5_mon,
    'Feature6': X6_mon,
    'Feature7': X7_mon,
    'Feature9': X9_mon,
    'Feature12': X12_mon,
    'Feature14': X14_mon,
})

data_unmon = pd.DataFrame({
    'Feature1': X1_unmon,
    'Feature5': X5_unmon,
    'Feature6': X6_unmon,
    'Feature7': X7_unmon,
    'Feature9': X9_unmon,
    'Feature12': X12_unmon,
   'Feature14': X14_unmon,
})

# %%
df_mon = pd.DataFrame(data_mon)
df_mon
# Out:
#        Feature1  Feature5  Feature6  Feature7  Feature9  Feature12  Feature14
# 0      0.007141      1300  0.085151  0.914849       121       2842       1421
# 1      0.019652       438  0.154440  0.845560        80       1036        518
# 2      0.008187      1240  0.086892  0.913108       118       2716       1358
# 3      0.009246      1324  0.084371  0.915629       122       2892       1446
# 4      0.007573      1291  0.081792  0.918208       115       2812       1406
# ...         ...       ...       ...       ...       ...        ...        ...
# 18995  0.004655      8815  0.065614  0.934386       619      18868       9434
# 18996  0.001567      9404  0.055444  0.944556       552      19912       9956
# 18997  0.001500      9373  0.058179  0.941821       579      19904       9952
# 18998  0.002006      9236  0.069514  0.930486       690      19852       9926
# 18999  0.001387      9168  0.076272  0.923728       757      19850       9925
#
# [19000 rows x 7 columns]

# %%
df_unmon = pd.DataFrame(data_unmon)
df_unmon
# Out:
#       Feature1  Feature5  Feature6  Feature7  Feature9  Feature12  Feature14
# 0     0.043101       101  0.223077  0.776923        29        260        130
# 1     0.001197      9189  0.074343  0.925657       738      19854       9927
# 2     0.049749       285  0.206128  0.793872        74        718        359
# 3     0.000922      9407  0.054383  0.945617       541      19896       9948
# 4     0.021376      2215  0.116826  0.883174       293       5016       2508
# ...        ...       ...       ...       ...       ...        ...        ...
# 9995  0.006988      4180  0.089919  0.910081       413       9186       4593
# 9996  0.007559      4663  0.087476  0.912524       447      10220       5110
# 9997  0.097028       302  0.163435  0.836565        59        722        361
# 9998  0.023307       413  0.188605  0.811395        96       1018        509
# 9999  0.000963      9668  0.032232  0.967768       322      19980       9990
#
# [10000 rows x 7 columns]

# %%
df_y_mon = pd.DataFrame(y_mon)
df_y_mon
# Out:
#         0
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
# ...    ..
# 18995  94
# 18996  94
# 18997  94
# 18998  94
# 18999  94
#
# [19000 rows x 1 columns]

# %% [markdown]
# ##unmon 데이터프레임으로 합치기

# %%
y_unmon = {'0': [-1] * 10000}
df_y_unmon = pd.DataFrame(y_unmon)
df_y_unmon
# Out:
#       0
# 0    -1
# 1    -1
# 2    -1
# 3    -1
# 4    -1
# ...  ..
# 9995 -1
# 9996 -1
# 9997 -1
# 9998 -1
# 9999 -1
#
# [10000 rows x 1 columns]

# %% [markdown]
# ##unmon + mon 합쳐서 total 데이터셋 만들기

# %%
'''
data_x_total = pd.DataFrame({
    'Feature1': [X1_unmon, X1_mon],
    'Feature5': [X5_unmon, X5_mon],
    'Feature6': [X6_unmon, X6_mon],
    'Feature7': [X7_unmon, X7_mon],
    'Feature9': [X9_unmon, X9_mon],
    'Feature12': [X12_unmon, X12_mon],
    'Feature14': [X14_unmon, X14_mon]
})
'''
data_total = pd.concat([df_unmon, df_mon], ignore_index=True)

# %%
data_total
# Out:
#        Feature1  Feature5  Feature6  Feature7  Feature9  Feature12  Feature14
# 0      0.043101       101  0.223077  0.776923        29        260        130
# 1      0.001197      9189  0.074343  0.925657       738      19854       9927
# 2      0.049749       285  0.206128  0.793872        74        718        359
# 3      0.000922      9407  0.054383  0.945617       541      19896       9948
# 4      0.021376      2215  0.116826  0.883174       293       5016       2508
# ...         ...       ...       ...       ...       ...        ...        ...
# 28995  0.004655      8815  0.065614  0.934386       619      18868       9434
# 28996  0.001567      9404  0.055444  0.944556       552      19912       9956
# 28997  0.001500      9373  0.058179  0.941821       579      19904       9952
# 28998  0.002006      9236  0.069514  0.930486       690      19852       9926
# 28999  0.001387      9168  0.076272  0.923728       757      19850       9925
#
# [29000 rows x 7 columns]

# %%
data_y_total = pd.concat([df_y_unmon.iloc[:,0], df_y_mon.iloc[:,0]], axis=0, ignore_index=True)
data_y_total = data_y_total.to_frame()  # Series를 DataFrame으로 변환

# %%
data_y_total
# Out:
#         0
# 0      -1
# 1      -1
# 2      -1
# 3      -1
# 4      -1
# ...    ..
# 28995  94
# 28996  94
# 28997  94
# 28998  94
# 28999  94
#
# [29000 rows x 1 columns]

# %% [markdown]
# ## 모델 Training

# %% [markdown]
# #1.logistic regression
#  (1.데이터샘플링,2.차원축소, 3.미니배치)

# %% [markdown]
# #1) Logistic Regression Accuracy (Data Sampling): 0.3310344827586207
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#
#     해당 오류는 결과값이 선형으로 수렴하지 않는다는 경고이다. 즉, 우리의 데이터는 복잡한 비선형 구조를 띄고 있다고 이해할 수 있다.

# %%
#1. 데이터 샘플링:
#무작위로 데이터를 샘플링하여 작은 규모의 훈련 데이터셋을 만들고 Logistic Regression 모델을 훈련하는 코드입니다.

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# 데이터 샘플링
sampled_data = data_total.sample(frac=0.1, random_state=42)
sampled_labels = data_y_total.loc[sampled_data.index]

# 데이터 분할
X_train_sampled, X_test_sampled, y_train_sampled, y_test_sampled = train_test_split(
    sampled_data, sampled_labels, test_size=0.2, random_state=42
)


# Logistic Regression 모델 훈련
clf_LR_sampled = LogisticRegression(max_iter=5000)
clf_LR_sampled.fit(X_train_sampled, y_train_sampled.values.ravel())

# 모델 평가
y_pred_sampled = clf_LR_sampled.predict(X_test_sampled)
accuracy_sampled = accuracy_score(y_test_sampled, y_pred_sampled)
classification_report_sampled = classification_report(y_test_sampled, y_pred_sampled, zero_division=1)

print("Logistic Regression Accuracy (Sampled Data):", accuracy_sampled)
print("Logistic Regression Classification Report (Sampled Data):")
print(classification_report_sampled)
# Out:
# Logistic Regression Accuracy (Sampled Data): 0.3310344827586207
# Logistic Regression Classification Report (Sampled Data):
#               precision    recall  f1-score   support
#
#           -1       0.33      0.99      0.50       194
#            0       1.00      0.00      0.00         4
#            1       1.00      0.00      0.00         4
#            2       1.00      0.00      0.00         4
#            3       1.00      0.00      0.00         5
#            4       1.00      0.00      0.00         5
#            5       1.00      0.00      0.00         6
#            6       1.00      0.00      0.00         5
#            7       1.00      0.00      0.00         3
#            8       1.00      0.00      0.00         8
#            9       1.00      0.00      0.00         9
#           10       1.00      0.00      0.00         7
#           11       1.00      0.00      0.00         5
#           12       1.00      0.00      0.00         2
#           13       1.00      0.00      0.00         1
#           14       1.00      0.00      0.00         1
#           15       1.00      0.00      0.00         6
#           16       1.00      0.00      0.00         3
#           17       1.00      0.00      0.00         5
#           18       1.00      0.00      0.00         5
#           19       1.00      0.00      0.00         6
#           20       1.00      0.00      0.00         2
#           21       1.00      0.00      0.00         3
#           22       1.00      0.00      0.00         3
#           23       1.00      0.00      0.00         1
#           24       1.00      0.00      0.00         3
#           25       1.00      0.00      0.00         2
#           26       1.00      0.00      0.00         5
#           27       1.00      0.00      0.00         2
#           28       1.00      0.00      0.00         9
#           29       1.00      0.00      0.00         4
#           30       1.00      0.00      0.00         3
#           31       1.00      0.00      0.00         3
#           32       1.00      0.00      0.00         4
#           33       1.00      0.00      0.00         5
#           34       1.00      0.00      0.00         3
#           35       1.00      0.00      0.00         3
#           36       1.00      0.00      0.00         4
#           37       1.00      0.00      0.00         4
#           38       1.00      0.00      0.00         4
#           39       1.00      0.00      0.00         4
#           40       1.00      0.00      0.00         6
#           41       1.00      0.00      0.00         1
#           43       1.00      0.00      0.00         8
#           44       1.00      0.00      0.00         3
#           45       1.00      0.00      0.00         3
#           46       1.00      0.00      0.00         3
#           47       1.00      0.00      0.00         3
#           48       1.00      0.00      0.00         4
#           49       1.00      0.00      0.00         5
#           50       1.00      0.00      0.00         2
#           51       1.00      0.00      0.00         3
#           52       1.00      0.00      0.00         5
#           53       1.00      0.00      0.00         1
#           54       1.00      0.00      0.00         3
#           55       1.00      0.00      0.00         5
#           56       1.00      0.00      0.00         3
#           57       1.00      0.00      0.00         3
#           58       1.00      0.00      0.00         4
#           59       1.00      0.00      0.00         8
#           60       1.00      0.00      0.00         3
#           61       1.00      0.00      0.00         2
#           62       1.00      0.00      0.00         6
#           63       1.00      0.00      0.00         2
#           64       1.00      0.00      0.00         4
#           65       1.00      0.00      0.00         3
#           66       1.00      0.00      0.00         5
#           67       1.00      0.00      0.00         6
#           68       1.00      0.00      0.00         4
#           69       1.00      0.00      0.00         5
#           70       1.00      0.00      0.00         1
#           71       1.00      0.00      0.00         5
#           72       1.00      0.00      0.00         9
#           73       1.00      0.00      0.00         4
#           74       1.00      0.00      0.00         4
#           75       1.00      0.00      0.00         5
#           76       1.00      0.00      0.00         8
#           77       1.00      0.00      0.00         5
#           78       1.00      0.00      0.00         6
#           79       1.00      0.00      0.00         4
#           80       1.00      0.00      0.00         3
#           81       1.00      0.00      0.00         4
#           82       1.00      0.00      0.00         2
#           83       1.00      0.00      0.00         5
#           84       1.00      0.00      0.00         4
#           85       1.00      0.00      0.00         8
#           86       0.00      0.00      0.00         3
#           87       1.00      0.00      0.00         3
#           88       1.00      0.00      0.00         2
#           89       0.00      0.00      0.00         3
#           90       1.00      0.00      0.00         4
#           91       1.00      0.00      0.00         4
#           92       1.00      0.00      0.00         2
#           93       1.00      0.00      0.00         3
#           94       1.00      0.00      0.00         7
#
#     accuracy                           0.33       580
#    macro avg       0.97      0.01      0.01       580
# weighted avg       0.77      0.33      0.17       580
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# 결과값을 해석하자면 -1로 할당된 class가 너무 많다. 즉, 클래스가 불균형한 것이다. 이런 경우 튜닝이 필요하다.

# %%
#1. data sampling 튜닝하기
from imblearn.over_sampling import RandomOverSampler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import train_test_split

# 데이터 샘플링 (Random Oversampling)
oversample = RandomOverSampler(sampling_strategy='auto', random_state=42)
X_over, y_over = oversample.fit_resample(X_train_sampled, y_train_sampled)

# 클래스 -1에 대한 가중치는 1로 설정
class_weights = {-1: 1}

# 나머지 클래스에 대한 가중치 설정
for i in range(94):
    if i != -1:
        class_weights[i] = 5 # 클래스 -1의 샘플 수에 비례하여 가중치 설정 (10,000 / 2000)


# Logistic Regression 모델 생성 시 class_weight 매개변수를 지정하여 가중치 부여
clf = LogisticRegression(class_weight=class_weights, max_iter=5000)

# 모델 학습
clf.fit(X_over, y_over)

# 모델 평가
y_pred = clf.predict(X_test_sampled)
accuracy = accuracy_score(y_test_sampled, y_pred)
classification_report_output = classification_report(y_test_sampled, y_pred, zero_division=1)

print("Logistic Regression Accuracy:", accuracy)
print("Logistic Regression Classification Report:")
print(classification_report_output)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-7d22ac866a22> in <cell line: 24>()
#      22
#      23 # 모델 학습
# ---> 24 clf.fit(X_over, y_over)
#      25
#      26 # 모델 평가
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1289             n_threads = 1
#    1290
# -> 1291         fold_coefs_ = Parallel(n_jobs=self.n_jobs, verbose=self.verbose, prefer=prefer)(
#    1292             path_func(
#    1293                 X,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py in __call__(self, iterable)
#      61             for delayed_func, args, kwargs in iterable
#      62         )
# ---> 63         return super().__call__(iterable_with_config)
#      64
#      65
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1861             output = self._get_sequential_output(iterable)
#    1862             next(output)
# -> 1863             return output if self.return_generator else list(output)
#    1864
#    1865         # Let's create an ID that uniquely identifies the current call. If the
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in _get_sequential_output(self, iterable)
#    1790                 self.n_dispatched_batches += 1
#    1791                 self.n_dispatched_tasks += 1
# -> 1792                 res = func(*args, **kwargs)
#    1793                 self.n_completed_tasks += 1
#    1794                 self.print_progress()
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py in __call__(self, *args, **kwargs)
#     121             config = {}
#     122         with config_context(**config):
# --> 123             return self.function(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py in _logistic_regression_path(X, y, pos_class, Cs, fit_intercept, max_iter, tol, verbose, solver, coef, class_weight, dual, penalty, intercept_scaling, multi_class, random_state, check_input, max_squared_sum, sample_weight, l1_ratio, n_threads)
#     448                 np.searchsorted(np.array([0, 1, 2, 3]), verbose)
#     449             ]
# --> 450             opt_res = optimize.minimize(
#     451                 func,
#     452                 w0,
#
# /usr/local/lib/python3.10/dist-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     708                                  **options)
#     709     elif meth == 'l-bfgs-b':
# --> 710         res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     711                                callback=callback, **options)
#     712     elif meth == 'tnc':
#
# /usr/local/lib/python3.10/dist-packages/scipy/optimize/_lbfgsb_py.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     363             # until the completion of the current minimization iteration.
#     364             # Overwrite f and g:
# --> 365             f, g = func_and_grad(x)
#     366         elif task_str.startswith(b'NEW_X'):
#     367             # new iteration
#
# /usr/local/lib/python3.10/dist-packages/scipy/optimize/_differentiable_functions.py in fun_and_grad(self, x)
#     283         if not np.array_equal(x, self.x):
#     284             self._update_x_impl(x)
# --> 285         self._update_fun()
#     286         self._update_grad()
#     287         return self.f, self.g
#
# /usr/local/lib/python3.10/dist-packages/scipy/optimize/_differentiable_functions.py in _update_fun(self)
#     249     def _update_fun(self):
#     250         if not self.f_updated:
# --> 251             self._update_fun_impl()
#     252             self.f_updated = True
#     253
#
# /usr/local/lib/python3.10/dist-packages/scipy/optimize/_differentiable_functions.py in update_fun()
#     153
#     154         def update_fun():
# --> 155             self.f = fun_wrapped(self.x)
#     156
#     157         self._update_fun_impl = update_fun
#
# /usr/local/lib/python3.10/dist-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     135             # Overwriting results in undefined behaviour because
#     136             # fun(self.x) will change self.x, with the two no longer linked.
# --> 137             fx = fun(np.copy(x), *args)
#     138             # Make sure the function returns a true scalar
#     139             if not np.isscalar(fx):
#
# /usr/local/lib/python3.10/dist-packages/scipy/optimize/_optimize.py in __call__(self, x, *args)
#      75     def __call__(self, x, *args):
#      76         """ returns the function value """
# ---> 77         self._compute_if_needed(x, *args)
#      78         return self._value
#      79
#
# /usr/local/lib/python3.10/dist-packages/scipy/optimize/_optimize.py in _compute_if_needed(self, x, *args)
#      69         if not np.all(x == self.x) or self._value is None or self.jac is None:
#      70             self.x = np.asarray(x).copy()
# ---> 71             fg = self.fun(x, *args)
#      72             self.jac = fg[1]
#      73             self._value = fg[0]
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_linear_loss.py in loss_gradient(self, coef, X, y, sample_weight, l2_reg_strength, n_threads, raw_prediction)
#     272
#     273         if raw_prediction is None:
# --> 274             weights, intercept, raw_prediction = self.weight_intercept_raw(coef, X)
#     275         else:
#     276             weights, intercept = self.weight_intercept(coef)
#
# KeyboardInterrupt:

# %% [markdown]
# #2)Logistic Regression Accuracy (PCA): 0.34844827586206895

# %%
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import train_test_split

# 데이터를 훈련 및 테스트 세트로 나누기
X_train, X_test, y_train, y_test = train_test_split(data_total, data_y_total, test_size=0.2, random_state=1)

# 차원 축소 모델 생성 및 훈련 데이터에 적용
pca = PCA(n_components=7)
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)

# Logistic Regression 모델 훈련
clf_LR_pca = LogisticRegression(max_iter=5000)
clf_LR_pca.fit(X_train_pca, y_train.values.ravel())

# 모델 평가
y_pred_pca = clf_LR_pca.predict(X_test_pca)
accuracy_pca = accuracy_score(y_test, y_pred_pca)
classification_report_pca = classification_report(y_test, y_pred_pca)

print("Logistic Regression Accuracy (PCA):", accuracy_pca)
print("Logistic Regression Classification Report (PCA):")
print(classification_report_pca)
# Out:
# Logistic Regression Accuracy (PCA): 0.34844827586206895
# Logistic Regression Classification Report (PCA):
#               precision    recall  f1-score   support
#
#           -1       0.35      0.98      0.52      2058
#            0       0.00      0.00      0.00        41
#            1       0.00      0.00      0.00        35
#            2       0.00      0.00      0.00        43
#            3       0.00      0.00      0.00        41
#            4       0.00      0.00      0.00        44
#            5       0.00      0.00      0.00        40
#            6       0.00      0.00      0.00        31
#            7       0.00      0.00      0.00        42
#            8       0.00      0.00      0.00        43
#            9       0.00      0.00      0.00        37
#           10       0.00      0.00      0.00        43
#           11       0.00      0.00      0.00        30
#           12       0.00      0.00      0.00        42
#           13       0.00      0.00      0.00        37
#           14       0.00      0.00      0.00        35
#           15       0.00      0.00      0.00        33
#           16       0.00      0.00      0.00        39
#           17       0.00      0.00      0.00        33
#           18       0.00      0.00      0.00        46
#           19       0.00      0.00      0.00        43
#           20       0.00      0.00      0.00        51
#           21       0.00      0.00      0.00        48
#           22       0.00      0.00      0.00        42
#           23       0.00      0.00      0.00        29
#           24       0.00      0.00      0.00        56
#           25       0.00      0.00      0.00        45
#           26       0.00      0.00      0.00        43
#           27       0.00      0.00      0.00        34
#           28       0.00      0.00      0.00        37
#           29       0.00      0.00      0.00        39
#           30       0.00      0.00      0.00        41
#           31       0.00      0.00      0.00        56
#           32       0.00      0.00      0.00        40
#           33       0.00      0.00      0.00        43
#           34       0.00      0.00      0.00        31
#           35       0.00      0.00      0.00        42
#           36       0.00      0.00      0.00        44
#           37       0.00      0.00      0.00        35
#           38       0.00      0.00      0.00        34
#           39       0.00      0.00      0.00        43
#           40       0.00      0.00      0.00        39
#           41       0.00      0.00      0.00        39
#           42       0.00      0.00      0.00        40
#           43       0.00      0.00      0.00        44
#           44       0.00      0.00      0.00        37
#           45       0.00      0.00      0.00        44
#           46       0.00      0.00      0.00        41
#           47       0.00      0.00      0.00        30
#           48       0.00      0.00      0.00        46
#           49       0.00      0.00      0.00        28
#           50       0.00      0.00      0.00        40
#           51       0.00      0.00      0.00        32
#           52       0.00      0.00      0.00        46
#           53       0.00      0.00      0.00        51
#           54       0.00      0.00      0.00        35
#           55       0.00      0.00      0.00        42
#           56       0.00      0.00      0.00        42
#           57       0.00      0.00      0.00        41
#           58       0.00      0.00      0.00        39
#           59       0.00      0.00      0.00        44
#           60       0.00      0.00      0.00        48
#           61       0.00      0.00      0.00        34
#           62       0.00      0.00      0.00        36
#           63       0.00      0.00      0.00        41
#           64       0.00      0.00      0.00        44
#           65       0.00      0.00      0.00        38
#           66       0.00      0.00      0.00        37
#           67       0.00      0.00      0.00        27
#           68       0.00      0.00      0.00        35
#           69       0.00      0.00      0.00        45
#           70       0.00      0.00      0.00        40
#           71       0.00      0.00      0.00        39
#           72       0.00      0.00      0.00        29
#           73       0.00      0.00      0.00        30
#           74       0.07      0.21      0.10        33
#           75       0.00      0.00      0.00        41
#           76       0.00      0.00      0.00        41
#           77       0.00      0.00      0.00        35
#           78       0.00      0.00      0.00        38
#           79       0.00      0.00      0.00        39
#           80       0.00      0.00      0.00        42
#           81       0.00      0.00      0.00        41
#           82       0.00      0.00      0.00        40
#           83       0.00      0.00      0.00        40
#           84       0.00      0.00      0.00        37
#           85       0.00      0.00      0.00        40
#           86       0.00      0.00      0.00        46
#           87       0.00      0.00      0.00        37
#           88       0.00      0.00      0.00        40
#           89       0.00      0.00      0.00        35
#           90       0.00      0.00      0.00        35
#           91       0.00      0.00      0.00        41
#           92       0.00      0.00      0.00        30
#           93       0.00      0.00      0.00        42
#           94       0.00      0.00      0.00        35
#
#     accuracy                           0.35      5800
#    macro avg       0.00      0.01      0.01      5800
# weighted avg       0.13      0.35      0.19      5800
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#튜닝 코드 여기에 적을 예정

# %% [markdown]
# #3)Logistic Regression Accuracy (Batch Training): 0.31517241379310346

# %%
#3.배치 훈련:
#배치 크기를 지정하여 모델을 여러 에폭동안 훈련하는 코드입니다.
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
import numpy as np

# 데이터 분할
X_train_batch, X_test_batch, y_train_batch, y_test_batch = train_test_split(
    data_total, data_y_total, test_size=0.2, random_state=42
)

# Logistic Regression 모델 훈련 (배치 훈련)
batch_size = 1000
num_epochs = 10

clf_LR_batch = SGDClassifier(max_iter=1000, random_state=42)

for epoch in range(num_epochs):
    # 무작위로 배치 생성
    indices = np.random.choice(len(X_train_batch), batch_size, replace=False)
    X_batch = X_train_batch.iloc[indices]
    y_batch = y_train_batch.iloc[indices].values.ravel()

    # 모델 훈련
    clf_LR_batch.partial_fit(X_batch, y_batch, classes=np.unique(y_train_batch))

# 모델 평가
y_pred_batch = clf_LR_batch.predict(X_test_batch)
accuracy_batch = accuracy_score(y_test_batch, y_pred_batch)
classification_report_batch = classification_report(y_test_batch, y_pred_batch)

print("Logistic Regression Accuracy (Batch Training):", accuracy_batch)

print("Logistic Regression Classification Report (Batch Training):")
print(classification_report_batch)
# Out:
# Logistic Regression Accuracy (Batch Training): 0.31517241379310346
# Logistic Regression Classification Report (Batch Training):
#               precision    recall  f1-score   support
#
#           -1       0.33      0.92      0.49      1979
#            0       0.00      0.00      0.00        42
#            1       0.00      0.00      0.00        50
#            2       0.00      0.00      0.00        43
#            3       0.00      0.00      0.00        30
#            4       0.00      0.00      0.00        47
#            5       0.00      0.00      0.00        39
#            6       0.00      0.00      0.00        40
#            7       0.00      0.00      0.00        33
#            8       0.00      0.00      0.00        43
#            9       0.00      0.00      0.00        44
#           10       0.00      0.00      0.00        45
#           11       0.00      0.00      0.00        46
#           12       0.00      0.00      0.00        49
#           13       0.00      0.00      0.00        43
#           14       0.00      0.00      0.00        31
#           15       0.00      0.00      0.00        51
#           16       0.00      0.00      0.00        32
#           17       0.00      0.00      0.00        45
#           18       0.00      0.00      0.00        37
#           19       0.00      0.00      0.00        36
#           20       0.00      0.00      0.00        40
#           21       0.00      0.00      0.00        37
#           22       0.00      0.00      0.00        48
#           23       0.00      0.00      0.00        46
#           24       0.00      0.00      0.00        52
#           25       0.00      0.00      0.00        40
#           26       0.00      0.00      0.00        36
#           27       0.00      0.00      0.00        50
#           28       0.00      0.00      0.00        43
#           29       0.00      0.00      0.00        44
#           30       0.00      0.00      0.00        42
#           31       0.00      0.00      0.00        34
#           32       0.00      0.00      0.00        43
#           33       0.00      0.00      0.00        37
#           34       0.00      0.00      0.00        36
#           35       0.00      0.00      0.00        43
#           36       0.00      0.00      0.00        37
#           37       0.00      0.00      0.00        39
#           38       0.00      0.00      0.00        40
#           39       0.00      0.00      0.00        35
#           40       0.00      0.00      0.00        35
#           41       0.00      0.00      0.00        32
#           42       0.00      0.00      0.00        42
#           43       0.00      0.00      0.00        51
#           44       0.00      0.00      0.00        36
#           45       0.00      0.00      0.00        35
#           46       0.00      0.00      0.00        34
#           47       0.00      0.00      0.00        35
#           48       0.00      0.00      0.00        44
#           49       0.00      0.00      0.00        43
#           50       0.00      0.00      0.00        38
#           51       0.00      0.00      0.00        36
#           52       0.00      0.00      0.00        42
#           53       0.00      0.00      0.00        43
#           54       0.00      0.00      0.00        40
#           55       0.00      0.00      0.00        40
#           56       0.00      0.00      0.00        38
#           57       0.00      0.00      0.00        46
#           58       0.00      0.00      0.00        41
#           59       0.00      0.00      0.00        46
#           60       0.00      0.00      0.00        46
#           61       0.00      0.00      0.00        37
#           62       0.00      0.00      0.00        38
#           63       0.00      0.00      0.00        41
#           64       0.00      0.00      0.00        35
#           65       0.00      0.00      0.00        28
#           66       0.00      0.00      0.00        39
#           67       0.00      0.00      0.00        44
#           68       0.00      0.00      0.00        37
#           69       0.00      0.00      0.00        44
#           70       0.00      0.00      0.00        45
#           71       0.00      0.00      0.00        42
#           72       0.00      0.00      0.00        47
#           73       0.00      0.00      0.00        38
#           74       0.00      0.00      0.00        33
#           75       0.00      0.00      0.00        42
#           76       0.00      0.00      0.00        42
#           77       0.00      0.00      0.00        35
#           78       0.00      0.00      0.00        50
#           79       0.00      0.00      0.00        39
#           80       0.00      0.00      0.00        40
#           81       0.00      0.00      0.00        40
#           82       0.00      0.00      0.00        35
#           83       0.00      0.00      0.00        35
#           84       0.00      0.00      0.00        34
#           85       0.00      0.00      0.00        52
#           86       0.00      0.00      0.00        38
#           87       0.00      0.00      0.00        31
#           88       0.00      0.00      0.00        39
#           89       0.00      0.00      0.00        33
#           90       0.00      0.00      0.00        32
#           91       0.00      0.00      0.00        44
#           92       0.00      0.00      0.00        38
#           93       0.00      0.00      0.00        40
#           94       0.00      0.00      0.00        43
#
#     accuracy                           0.32      5800
#    macro avg       0.00      0.01      0.01      5800
# weighted avg       0.11      0.32      0.17      5800
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # 2. Decision tree

# %% [markdown]
# #Decision Tree Accuracy (in %): 46.02%

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(data_total, data_y_total, test_size=0.2, random_state=42)

# 결정 트리 모델 생성 및 훈련
clf_decision_tree = DecisionTreeClassifier(random_state=42)
clf_decision_tree.fit(X_train, y_train)

# 모델 평가
y_pred_decision_tree = clf_decision_tree.predict(X_test)
accuracy_decision_tree = accuracy_score(y_test, y_pred_decision_tree)
classification_report_decision_tree = classification_report(y_test, y_pred_decision_tree)

print("Decision Tree Accuracy (in %): {:.2f}%".format(accuracy_decision_tree * 100))

'''
print("Decision Tree Classification Report:")
print(classification_report_decision_tree)
'''
# Out:
# Decision Tree Accuracy (in %): 46.02%
# '\nprint("Decision Tree Classification Report:")\nprint(classification_report_decision_tree)\n'

# %% [markdown]
# # 튜닝한 Decision Tree
# 1)
#
# Best parameters: {'max_depth': 20, 'min_samples_leaf': 3, 'min_samples_split': 2}
#
# Accuracy of the best model: 0.4874137931034483

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

# Decision Tree 모델과 관련된 하이퍼파라미터 그리드 설정
param_grid = {
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 3, 4],
    'min_samples_leaf': [1, 2, 3]
}

# GridSearchCV를 사용하여 최적의 하이퍼파라미터 찾기
grid_search = GridSearchCV(DecisionTreeClassifier(random_state=42), param_grid, cv=5)
grid_search.fit(X_train, y_train)

# 최적의 하이퍼파라미터 출력
print("Best parameters:", grid_search.best_params_)

# 최적의 모델로 평가
best_model = grid_search.best_estimator_
accuracy_best_model = best_model.score(X_test, y_test)
print("Accuracy of the best model:", accuracy_best_model)
# Out:
# Best parameters: {'max_depth': 20, 'min_samples_leaf': 3, 'min_samples_split': 2}
# Accuracy of the best model: 0.4874137931034483

# %% [markdown]
# ## 3. Random Forest

# %% [markdown]
# #Random Forest Accuracy (in %): 54.48%

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# 랜덤 포레스트 모델 생성 및 훈련
clf_random_forest = RandomForestClassifier(random_state=42)
clf_random_forest.fit(X_train, y_train.values.ravel())

# 모델 평가
y_pred_random_forest = clf_random_forest.predict(X_test)
accuracy_random_forest = accuracy_score(y_test, y_pred_random_forest)
classification_report_random_forest = classification_report(y_test, y_pred_random_forest)

print("Random Forest Accuracy (in %): {:.2f}%".format(accuracy_random_forest * 100))

'''
print("Random Forest Classification Report:")
print(classification_report_random_forest)
'''
# Out:
# Random Forest Accuracy (in %): 54.48%
# '\nprint("Random Forest Classification Report:")\nprint(classification_report_random_forest)\n'

# %% [markdown]
# #튜닝 :Accuracy of the best model: 0.5598275862068965
#
# Best parameters: {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 784}

# %%
from scipy.stats import randint
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV

# 튜닝할 하이퍼파라미터 범위 설정
param_dist = {
    'n_estimators': randint(400, 800),  # 100에서 1000 사이의 랜덤한 정수
    'max_depth': [None] + list(randint(10, 30).rvs(5)),  # None과 10에서 30 사이의 랜덤한 정수
    'min_samples_split': randint(3, 15),  # 2에서 20 사이의 랜덤한 정수
    'min_samples_leaf': randint(1, 5),   # 1에서 10 사이의 랜덤한 정수
    'max_features': ['sqrt', 'auto']
}

# RandomForestClassifier 생성
clf = RandomForestClassifier(random_state=42)

# RandomizedSearchCV를 사용하여 튜닝
random_search = RandomizedSearchCV(clf, param_distributions=param_dist, n_iter=50, cv=5, random_state=42)
random_search.fit(X_train, y_train.values.ravel())

# 최적의 하이퍼파라미터 출력
print("Best parameters:", random_search.best_params_)

# 최적의 모델로 평가
best_model = random_search.best_estimator_
accuracy_best_model = best_model.score(X_test, y_test)
print("Accuracy of the best model:", accuracy_best_model)

#이거 오래걸림...
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# Best parameters: {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 784}
# Accuracy of the best model: 0.5598275862068965

# %% [markdown]
# ## 4. k-NN

# %% [markdown]
# #KNN Accuracy (in %): 45.14%

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report

# KNN 모델 생성 및 훈련
clf_knn = KNeighborsClassifier()
clf_knn.fit(X_train, y_train)

# y_train, y_test를 1차원 배열로 변환
y_train = np.ravel(y_train)
y_test = np.ravel(y_test)

# 변환 후 KNN 모델 훈련 및 예측
clf_knn.fit(X_train, y_train)
y_pred_knn = clf_knn.predict(X_test)

# 모델 평가
y_pred_knn = clf_knn.predict(X_test)
accuracy_knn = accuracy_score(y_test, y_pred_knn)
classification_report_knn = classification_report(y_test, y_pred_knn)

print("KNN Accuracy (in %): {:.2f}%".format(accuracy_knn * 100))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNN Accuracy (in %): 45.14%

# %% [markdown]
# #튜닝한 K-NN
#
# 1)
# Best K value: 9
#
# Tuned KNN Accuracy (in %): 45.84%

# %%
from sklearn.model_selection import GridSearchCV

# 탐색할 이웃 수의 범위 지정
param_grid = {'n_neighbors': range(1, 21)}

# 그리드 서치를 사용하여 최적의 이웃 수 찾기
grid_search = GridSearchCV(KNeighborsClassifier(), param_grid, cv=5)
grid_search.fit(X_train, y_train)

# 최적의 이웃 수 출력
print("Best K value:", grid_search.best_params_['n_neighbors'])

# 최적의 이웃 수로 모델 재훈련
best_k = grid_search.best_params_['n_neighbors']
clf_knn_tuned = KNeighborsClassifier(n_neighbors=best_k)
clf_knn_tuned.fit(X_train, y_train)

# 튜닝된 모델 평가
y_pred_knn_tuned = clf_knn_tuned.predict(X_test)
accuracy_knn_tuned = accuracy_score(y_test, y_pred_knn_tuned)
classification_report_knn_tuned = classification_report(y_test, y_pred_knn_tuned)

print("Tuned KNN Accuracy (in %): {:.2f}%".format(accuracy_knn_tuned * 100))
print("Classification Report for Tuned KNN:\n", classification_report_knn_tuned)
# Out:
# Best K value: 9
# Tuned KNN Accuracy (in %): 45.84%
# Classification Report for Tuned KNN:
#                precision    recall  f1-score   support
#
#           -1       0.45      0.71      0.55      1979
#            0       0.44      0.26      0.33        42
#            1       0.17      0.04      0.06        50
#            2       0.52      0.56      0.54        43
#            3       0.52      0.47      0.49        30
#            4       0.44      0.26      0.32        47
#            5       0.37      0.28      0.32        39
#            6       0.45      0.47      0.46        40
#            7       0.31      0.24      0.27        33
#            8       0.41      0.28      0.33        43
#            9       0.26      0.11      0.16        44
#           10       0.54      0.33      0.41        45
#           11       0.32      0.15      0.21        46
#           12       0.69      0.73      0.71        49
#           13       0.26      0.14      0.18        43
#           14       0.38      0.26      0.31        31
#           15       0.56      0.45      0.50        51
#           16       0.62      0.50      0.55        32
#           17       0.39      0.16      0.22        45
#           18       0.33      0.46      0.38        37
#           19       0.38      0.33      0.35        36
#           20       0.66      0.82      0.73        40
#           21       0.11      0.03      0.04        37
#           22       0.20      0.08      0.12        48
#           23       0.55      0.50      0.52        46
#           24       0.00      0.00      0.00        52
#           25       0.57      0.40      0.47        40
#           26       0.57      0.67      0.62        36
#           27       0.32      0.14      0.19        50
#           28       0.64      0.49      0.55        43
#           29       0.38      0.30      0.33        44
#           30       0.45      0.21      0.29        42
#           31       0.61      0.41      0.49        34
#           32       0.31      0.21      0.25        43
#           33       0.53      0.49      0.51        37
#           34       0.17      0.06      0.08        36
#           35       0.47      0.42      0.44        43
#           36       0.27      0.27      0.27        37
#           37       0.25      0.10      0.15        39
#           38       0.36      0.30      0.33        40
#           39       0.37      0.31      0.34        35
#           40       0.39      0.34      0.36        35
#           41       0.48      0.34      0.40        32
#           42       0.33      0.14      0.20        42
#           43       0.70      0.55      0.62        51
#           44       0.75      0.92      0.83        36
#           45       0.22      0.17      0.19        35
#           46       0.62      0.24      0.34        34
#           47       0.33      0.17      0.23        35
#           48       0.64      0.20      0.31        44
#           49       0.65      0.65      0.65        43
#           50       0.30      0.21      0.25        38
#           51       0.24      0.11      0.15        36
#           52       0.33      0.14      0.20        42
#           53       0.47      0.16      0.24        43
#           54       0.37      0.38      0.37        40
#           55       0.38      0.12      0.19        40
#           56       0.56      0.76      0.64        38
#           57       0.36      0.11      0.17        46
#           58       0.53      0.68      0.60        41
#           59       0.43      0.28      0.34        46
#           60       0.35      0.24      0.29        46
#           61       0.09      0.05      0.07        37
#           62       0.39      0.34      0.37        38
#           63       0.21      0.07      0.11        41
#           64       0.28      0.26      0.27        35
#           65       0.34      0.39      0.37        28
#           66       0.49      0.46      0.47        39
#           67       0.42      0.34      0.37        44
#           68       0.44      0.19      0.26        37
#           69       0.43      0.20      0.28        44
#           70       0.84      0.84      0.84        45
#           71       0.50      0.26      0.34        42
#           72       0.49      0.40      0.44        47
#           73       0.47      0.50      0.49        38
#           74       0.14      0.09      0.11        33
#           75       0.68      0.93      0.79        42
#           76       0.75      0.86      0.80        42
#           77       0.17      0.03      0.05        35
#           78       0.22      0.08      0.12        50
#           79       0.20      0.10      0.14        39
#           80       0.56      0.57      0.57        40
#           81       0.41      0.23      0.29        40
#           82       0.77      0.49      0.60        35
#           83       0.48      0.46      0.47        35
#           84       0.26      0.18      0.21        34
#           85       0.69      0.52      0.59        52
#           86       0.82      0.82      0.82        38
#           87       0.23      0.23      0.23        31
#           88       0.67      0.31      0.42        39
#           89       0.33      0.24      0.28        33
#           90       0.53      0.31      0.39        32
#           91       0.57      0.30      0.39        44
#           92       0.27      0.11      0.15        38
#           93       0.44      0.42      0.43        40
#           94       0.00      0.00      0.00        43
#
#     accuracy                           0.46      5800
#    macro avg       0.42      0.33      0.36      5800
# weighted avg       0.43      0.46      0.42      5800

# %% [markdown]
# ##5. SVM (rbf, linear)

# %% [markdown]
# ##1) RBF SVM Accuracy (in %): 34.12%

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

# SVM 모델 생성 및 훈련
svm_classifier = SVC(kernel='rbf', C=1.0, gamma='scale')  # rbf 커널 사용, C와 gamma 값은 예시입니다.
svm_classifier.fit(X_train, y_train)

# 모델 평가
y_pred_svm = svm_classifier.predict(X_test)
accuracy_svm = accuracy_score(y_test, y_pred_svm)
classification_report_svm = classification_report(y_test, y_pred_svm)

print("SVM Accuracy (in %): {:.2f}%".format(accuracy_svm * 100))
print("Classification Report for SVM:\n", classification_report_svm)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVM Accuracy (in %): 34.12%
# Classification Report for SVM:
#                precision    recall  f1-score   support
#
#           -1       0.34      1.00      0.51      1979
#            0       0.00      0.00      0.00        42
#            1       0.00      0.00      0.00        50
#            2       0.00      0.00      0.00        43
#            3       0.00      0.00      0.00        30
#            4       0.00      0.00      0.00        47
#            5       0.00      0.00      0.00        39
#            6       0.00      0.00      0.00        40
#            7       0.00      0.00      0.00        33
#            8       0.00      0.00      0.00        43
#            9       0.00      0.00      0.00        44
#           10       0.00      0.00      0.00        45
#           11       0.00      0.00      0.00        46
#           12       0.00      0.00      0.00        49
#           13       0.00      0.00      0.00        43
#           14       0.00      0.00      0.00        31
#           15       0.00      0.00      0.00        51
#           16       0.00      0.00      0.00        32
#           17       0.00      0.00      0.00        45
#           18       0.00      0.00      0.00        37
#           19       0.00      0.00      0.00        36
#           20       0.00      0.00      0.00        40
#           21       0.00      0.00      0.00        37
#           22       0.00      0.00      0.00        48
#           23       0.00      0.00      0.00        46
#           24       0.00      0.00      0.00        52
#           25       0.00      0.00      0.00        40
#           26       0.00      0.00      0.00        36
#           27       0.00      0.00      0.00        50
#           28       0.00      0.00      0.00        43
#           29       0.00      0.00      0.00        44
#           30       0.00      0.00      0.00        42
#           31       0.00      0.00      0.00        34
#           32       0.00      0.00      0.00        43
#           33       0.00      0.00      0.00        37
#           34       0.00      0.00      0.00        36
#           35       0.00      0.00      0.00        43
#           36       0.00      0.00      0.00        37
#           37       0.00      0.00      0.00        39
#           38       0.00      0.00      0.00        40
#           39       0.00      0.00      0.00        35
#           40       0.00      0.00      0.00        35
#           41       0.00      0.00      0.00        32
#           42       0.00      0.00      0.00        42
#           43       0.00      0.00      0.00        51
#           44       0.00      0.00      0.00        36
#           45       0.00      0.00      0.00        35
#           46       0.00      0.00      0.00        34
#           47       0.00      0.00      0.00        35
#           48       0.00      0.00      0.00        44
#           49       0.00      0.00      0.00        43
#           50       0.00      0.00      0.00        38
#           51       0.00      0.00      0.00        36
#           52       0.00      0.00      0.00        42
#           53       0.00      0.00      0.00        43
#           54       0.00      0.00      0.00        40
#           55       0.00      0.00      0.00        40
#           56       0.00      0.00      0.00        38
#           57       0.00      0.00      0.00        46
#           58       0.00      0.00      0.00        41
#           59       0.00      0.00      0.00        46
#           60       0.00      0.00      0.00        46
#           61       0.00      0.00      0.00        37
#           62       0.00      0.00      0.00        38
#           63       0.00      0.00      0.00        41
#           64       0.00      0.00      0.00        35
#           65       0.00      0.00      0.00        28
#           66       0.00      0.00      0.00        39
#           67       0.00      0.00      0.00        44
#           68       0.00      0.00      0.00        37
#           69       0.00      0.00      0.00        44
#           70       0.00      0.00      0.00        45
#           71       0.00      0.00      0.00        42
#           72       0.00      0.00      0.00        47
#           73       0.00      0.00      0.00        38
#           74       0.00      0.00      0.00        33
#           75       0.00      0.00      0.00        42
#           76       0.00      0.00      0.00        42
#           77       0.00      0.00      0.00        35
#           78       0.00      0.00      0.00        50
#           79       0.00      0.00      0.00        39
#           80       0.00      0.00      0.00        40
#           81       0.00      0.00      0.00        40
#           82       0.00      0.00      0.00        35
#           83       0.00      0.00      0.00        35
#           84       0.00      0.00      0.00        34
#           85       0.00      0.00      0.00        52
#           86       0.00      0.00      0.00        38
#           87       0.00      0.00      0.00        31
#           88       0.00      0.00      0.00        39
#           89       0.00      0.00      0.00        33
#           90       0.00      0.00      0.00        32
#           91       0.00      0.00      0.00        44
#           92       0.00      0.00      0.00        38
#           93       0.00      0.00      0.00        40
#           94       0.00      0.00      0.00        43
#
#     accuracy                           0.34      5800
#    macro avg       0.00      0.01      0.01      5800
# weighted avg       0.12      0.34      0.17      5800
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# #튜닝한 RGF SVM : 51.57%

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

# 데이터 스케일링
scaler = StandardScaler()

y_train = y_train.ravel()
y_test = y_test.values.ravel()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)


# SVM 모델 생성
svm_classifier = SVC()

# 탐색할 매개변수 그리드 설정
param_grid = {
    'C': [0.1, 1, 10, 100],
    'gamma': ['scale', 'auto', 0.1, 1, 10]
}

# 그리드 서치를 사용하여 최적의 매개변수 찾기
grid_search = GridSearchCV(svm_classifier, param_grid, cv=5)
grid_search.fit(X_train_scaled, y_train)

# 최적의 매개변수 출력
print("Best parameters:", grid_search.best_params_)

# 최적의 매개변수로 모델 재훈련
best_C = grid_search.best_params_['C']
best_gamma = grid_search.best_params_['gamma']
svm_classifier_tuned = SVC(C=best_C, gamma=best_gamma)
svm_classifier_tuned.fit(X_train_scaled, y_train)

# 튜닝된 모델 평가
y_pred_tuned = svm_classifier_tuned.predict(X_test_scaled)
accuracy_tuned = accuracy_score(y_test, y_pred_tuned)
print("Tuned SVM Accuracy (in %): {:.2f}%".format(accuracy_tuned * 100))
# Out:
# Best parameters: {'C': 100, 'gamma': 10}
# Tuned SVM Accuracy (in %): 51.57%

# %% [markdown]
# ##2) Linear SVM: 0.11137931034482759

# %%
from sklearn.svm import SVC, LinearSVC
from sklearn.metrics import accuracy_score

# 선형 커널 SVM 모델 학습 및 평가
svm_linear = LinearSVC(C=10000, loss='hinge')
svm_linear.fit(X_train, y_train)
y_pred_linear = svm_linear.predict(X_test)
accuracy_linear = accuracy_score(y_test, y_pred_linear)
print("Accuracy of Linear SVM:", accuracy_linear)
# Out:
# Accuracy of Linear SVM: 0.11137931034482759
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %% [markdown]
# #튜닝한 Linear SVM
#
# 1)

# %%
from sklearn.model_selection import GridSearchCV

# 탐색할 매개변수 그리드 정의
param_grid = {'C': [0.1, 1, 10, 100, 1000],
              'loss': ['hinge', 'squared_hinge']}

# SVC 모델 객체 생성
svm = LinearSVC()

# GridSearchCV 객체 생성 및 훈련 데이터에 대해 그리드 탐색 수행
grid_search = GridSearchCV(svm, param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train, y_train)

# 최적의 하이퍼파라미터와 그 때의 정확도 출력
print("Best Parameters:", grid_search.best_params_)
print("Best Cross-Validation Accuracy:", grid_search.best_score_)

# 최적의 모델에 대해 테스트 세트로 성능 평가
best_svm = grid_search.best_estimator_
test_accuracy = best_svm.score(X_test, y_test)
print("Test Set Accuracy of Best Model:", test_accuracy)
